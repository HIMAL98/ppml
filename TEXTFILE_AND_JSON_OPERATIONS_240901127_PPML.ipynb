# %% [markdown]
# <a href="https://colab.research.google.com/github/HIMAL98/ppml/blob/main/TEXTFILE_AND_JSON_OPERATIONS_240901127_PPML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f=open("textfile.txt",'w')
f.write("first line\n")
f.write("Second line\n")
f.write("third line\n")
f.close()
k=open("textfile.txt",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()

m=open("textfile.txt",'a')
m.write("fourth line\n")
m.write("fifth line\n")
m.close()
p=open("textfile.txt",'r')
print(p.read())
p.close()


with open("textfile.txt",'r')as file:
    lines=file.readlines()
    print(lines)


import json
x='{"name":"John","age":"30","city":"New york"}'
y=json.loads(x)
print(y["age"])


data={"name":"john","age":30,"city":"New york"}
json_data=json.dumps(data)
print(json_data)
# Out:
# first line
#
# Second line
#
# third line
#
# first line
# Second line
# third line
# fourth line
# fifth line
#
# ['first line\n', 'Second line\n', 'third line\n', 'fourth line\n', 'fifth line\n']
# 30
# {"name": "john", "age": 30, "city": "New york"}
