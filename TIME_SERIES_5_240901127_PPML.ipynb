# %% [markdown]
# <a href="https://colab.research.google.com/github/HIMAL98/ppml/blob/main/TIME_SERIES_5_240901127_PPML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

np.random.seed(0)  # ensures same random values every run

dates = [
    datetime(2020, 1, 5),
    datetime(2020, 1, 10),
    datetime(2020, 1, 15),
    datetime(2020, 1, 20),
    datetime(2020, 1, 25)
]

ts = pd.Series(np.random.randn(5), index=dates)

ts  # just display, don't use print()

res=ts.truncate(after="1/15/2020")
print("\nTruncate method to truncate datetime series \n", res)


da=pd.date_range("10/1/2022", periods=10, freq="W-SUN")
print("\nDate range with day periods.\n",da)


date=pd.DatetimeIndex(["1/1/2020","1/2/2020","1/2/2020","1/2/2020","1/3/2020"])
ts1=pd.Series(np.arange(5), index=date)
print("\nDuplicate datetime index:\n",ts1)


group=ts1.groupby(level=0)
print("\nRepeated date counts:\n",group.count())

long_df=pd.DataFrame(np.random.randn(10,4),index=da,columns=list("ABCD"))
print("\nMulti-column DataFrame with datatime index:\n",long_df)
# Out:
# Truncate method to truncate datetime series
#  2020-01-05    1.764052
# 2020-01-10    0.400157
# 2020-01-15    0.978738
# dtype: float64
#
# Date range with day periods.
#  DatetimeIndex(['2022-10-02', '2022-10-09', '2022-10-16', '2022-10-23',
#                '2022-10-30', '2022-11-06', '2022-11-13', '2022-11-20',
#                '2022-11-27', '2022-12-04'],
#               dtype='datetime64[ns]', freq='W-SUN')
#
# Duplicate datetime index:
#  2020-01-01    0
# 2020-01-02    1
# 2020-01-02    2
# 2020-01-02    3
# 2020-01-03    4
# dtype: int64
#
# Repeated date counts:
#  2020-01-01    1
# 2020-01-02    3
# 2020-01-03    1
# dtype: int64
#
# Multi-column DataFrame with datatime index:
#                     A         B         C         D
# 2022-10-02 -0.977278  0.950088 -0.151357 -0.103219
# 2022-10-09  0.410599  0.144044  1.454274  0.761038
# 2022-10-16  0.121675  0.443863  0.333674  1.494079
# 2022-10-23 -0.205158  0.313068 -0.854096 -2.552990
# 2022-10-30  0.653619  0.864436 -0.742165  2.269755
# 2022-11-06 -1.454366  0.045759 -0.187184  1.532779
# 2022-11-13  1.469359  0.154947  0.378163 -0.887786
# 2022-11-20 -1.980796 -0.347912  0.156349  1.230291
# 2022-11-27  1.202380 -0.387327 -0.302303 -1.048553
# 2022-12-04 -1.420018 -1.706270  1.950775 -0.509652
