# %% [markdown]
# <a href="https://colab.research.google.com/github/HIMAL98/ppml/blob/main/TIME_SERIES_240901127_PPML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
cd=datetime.datetime.now()
print(cd)

res=cd.strftime("%y")
print("\nTwo-digit year:", res)

res1=cd.strftime("%Y")
print("\nFour-digit year:", res1)

res=cd.strftime("%m")
print("\nTwo-digit month [01, 12]:",res)

res=cd.strftime("%b")
print("\nShort version of month", res)

res=cd.strftime("%B")
print("\nFull name of month:",res)

res=cd.strftime("%j")
print("\nDays of the year:", res)

res=cd.strftime("%D")
print("\nShortcut for %m/%d/%y (e.g., 04/18/12):", res)

res=cd.strftime("%d")
print("\nTwo-digit day [01, 31]:", res)

res=cd.strftime("%a")
print("\nShort version of day", res)

res=cd.strftime("A")
print("\nFull name of a day:", res)

res=cd.strftime("%H")
print("\nHour (24-hour clock) [00, 23]:",res)

res=cd.strftime("%I")
print("\nHour (12-hour clock) [01, 12]",res)

res=cd.strftime("%M")
print("\nTwo-digit minute [00, 59]:", res)

res=cd.strftime("%S")
print("\nSecond (00, 61] (seconds 60, 61 account for leap seconds):",res)

res=cd.strftime("%F")
print("\nShortcut for %Y-%m-%d (eg, 2012-4-18):",res)

res=cd.strftime("%f")
print("\nMicrosecond as an integer, zero-padded (from 000000 to 999999);", res)

res=cd.strftime("%p")
print("\nLocale equivalent of AM or PM:", res)

res=cd.strftime("%X")
print("\nLocale-appropriate time (e.g., '04:24:12 PM'):",res)
# Out:
# 2026-04-26 20:41:29.597802
#
# Two-digit year: 26
#
# Four-digit year: 2026
#
# Two-digit month [01, 12]: 04
#
# Short version of month Apr
#
# Full name of month: April
#
# Days of the year: 116
#
# Shortcut for %m/%d/%y (e.g., 04/18/12): 04/26/26
#
# Two-digit day [01, 31]: 26
#
# Short version of day Sun
#
# Full name of a day: A
#
# Hour (24-hour clock) [00, 23]: 20
#
# Hour (12-hour clock) [01, 12] 08
#
# Two-digit minute [00, 59]: 41
#
# Second (00, 61] (seconds 60, 61 account for leap seconds): 29
#
# Shortcut for %Y-%m-%d (eg, 2012-4-18): 2026-04-26
#
# Microsecond as an integer, zero-padded (from 000000 to 999999); 597802
#
# Locale equivalent of AM or PM: PM
#
# Locale-appropriate time (e.g., '04:24:12 PM'): 20:41:29
