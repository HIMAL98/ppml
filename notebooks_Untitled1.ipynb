# %%
                           import numpy as np  
a = np.array([[1, 2, 4], [5, 8, 7]]) 
print ("Array created using passed list:\n", a)
# Out:
#   Cell In[1], line 1
#     import numpy as np
#     ^
# IndentationError: unexpected indent
